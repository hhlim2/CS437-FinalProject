# %%
# !pip install split-folders
# !pip install tensorflow
# !pip install numpy
# !pip install tensorflow_addons
# !pip install pillow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
# Out:
# WARNING:tensorflow:From c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ...

# %%
#splitfolders.ratio(r'C:\Users\hhben\Desktop\cs437\Final Project\data', output="output", seed=1337, ratio=(.85, 0.15))

# %%
image_size = (256,256)
batch_size = 32

# %%
train_ds = image_dataset_from_directory('data',
                                           subset='training',
                                           image_size=image_size,
                                           labels='inferred',
                                           validation_split=.2,
                                           seed=10,
                                           label_mode='categorical',
                                           color_mode='rgb',
                                           batch_size=batch_size)

val_ds = image_dataset_from_directory('data',
                                           subset='validation',
                                           image_size=image_size,
                                           labels='inferred',
                                           validation_split=.2,
                                           seed=10,
                                           label_mode='categorical',
                                           color_mode='rgb',
                                           batch_size=batch_size)
# Out:
# Found 7553 files belonging to 2 classes.
# Using 6043 files for training.
# Found 7553 files belonging to 2 classes.
# Using 1510 files for validation.

# %%
num_classes=2

metrics = [
      keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'),
]
# Out:
# WARNING:tensorflow:From c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:585: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model1 = keras.Sequential()

model1.add(InputLayer(input_shape=(image_size + (3,))))

model1.add(Flatten())

model1.add(Dense(100, activation='relu'))
model1.add(Dense(100, activation='relu'))
model1.add(Dense(100, activation='relu'))

model1.add(Dense(num_classes, activation='softmax'))

model1.summary()

model1.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=metrics)

model1.fit(train_ds, epochs=10, validation_data=val_ds)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 196608)            0
#
#  dense (Dense)               (None, 100)               19660900
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 2)                 202
#
# ...
# Total params: 19681302 (75.08 MB)
# Trainable params: 19681302 (75.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# ...

# %%
def create_model2():
  model = tf.keras.Sequential([
  tf.keras.layers.InputLayer(input_shape=(image_size + (3,))),
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])
  model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=metrics)

  return model

# %%
model2 = create_model2()

model2.fit(train_ds, epochs=10, validation_data=val_ds)
model2.save("model.keras", format='keras')
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 189/189 [==============================] - 42s 213ms/step - loss: 0.4178 - categorical_accuracy: 0.8147 - auc: 0.8996 - prc: 0.8892 - val_loss: 0.3097 - val_categorical_accuracy: 0.8742 - val_auc: 0.9439 - val_prc: 0.9414
# Epoch 2/10
# 189/189 [==============================] - 38s 200ms/step - loss: 0.2416 - categorical_accuracy: 0.9034 - auc: 0.9642 - prc: 0.9637 - val_loss: 0.2401 - val_categorical_accuracy: 0.9086 - val_auc: 0.9642 - val_prc: 0.9617
# Epoch 3/10
# 189/189 [==============================] - 40s 213ms/step - loss: 0.1906 - categorical_accuracy: 0.9255 - auc: 0.9776 - prc: 0.9771 - val_loss: 0.2244 - val_categorical_accuracy: 0.9166 - val_auc: 0.9686 - val_prc: 0.9670
# Epoch 4/10
# ...

# %%
CNN = Sequential()
CNN.add(InputLayer(input_shape=(image_size + (3,))))
CNN.add(Conv2D(filters=10, kernel_size=3, activation='relu', padding='same'))
CNN.add(MaxPooling2D())
CNN.add(Conv2D(filters=20, kernel_size=3, activation='relu', padding='same'))
CNN.add(MaxPooling2D())
CNN.add(Conv2D(filters=30, kernel_size=3, activation='relu', padding='same'))
CNN.add(GlobalAveragePooling2D())
CNN.add(Dense(20, activation='relu'))
CNN.add(Dense(num_classes, activation='softmax'))
CNN.summary()

CNN.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=metrics)

CNN.fit(train_ds, epochs=10, validation_data=val_ds)
# Out:
# WARNING:tensorflow:From c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 256, 256, 10)      280
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 10)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 20)      1820
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 20)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 30)        5430
#
#  global_average_pooling2d (  (None, 30)                0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 20)                620
#
#  dense_5 (Dense)             (None, 2)                 42
#
# ...
# Total params: 8192 (32.00 KB)
# Trainable params: 8192 (32.00 KB)
# ...

# %%
resize_and_rescale = tf.keras.Sequential([
  keras.layers.Resizing(256,256),
  keras.layers.Rescaling(1./255)])

data_augmentation = keras.Sequential(
    [
        keras.layers.RandomFlip("horizontal_and_vertical"),
        keras.layers.RandomRotation(0.2),
        keras.layers.RandomZoom(0.1),
    ]
)

def make_model3(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = resize_and_rescale(inputs)
    x = data_augmentation(x)

    # Entry block
    x = keras.layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation("relu")(x)

    x = keras.layers.Conv2D(64, 3, padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = keras.layers.Activation("relu")(x)
        x = keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = keras.layers.BatchNormalization()(x)

        x = keras.layers.Activation("relu")(x)
        x = keras.layers.SeparableConv2D(size, 3, padding="same")(x)
        x = keras.layers.BatchNormalization()(x)

        x = keras.layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = keras.layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = keras.layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = keras.layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation("relu")(x)

    x = keras.layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = keras.layers.Dropout(0.5)(x)
    outputs = keras.layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


xception = make_model3(input_shape=image_size + (3,), num_classes=2)
xception.summary()


callbacks=[
        keras.callbacks.EarlyStopping(patience=10, verbose=1, monitor='val_F2', mode='max', restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=3, verbose=1),
    ]
xception.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=metrics,
)
xception.fit(
    train_ds, epochs=10, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_6 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  sequential_6 (Sequential)   (None, 256, 256, 3)          0         ['input_6[0][0]']
#
#  sequential_7 (Sequential)   (None, 256, 256, 3)          0         ['sequential_6[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         896       ['sequential_7[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 32)         128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)         18496     ['activation_22[0][0]']
#
# ...

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
vgg_base = VGG19(include_top=False, weights= 'imagenet', input_shape=(256, 256, 3))
vgg_model = keras.models.Sequential()
vgg_model.add(Input(shape=image_size + (3,)))
vgg_model.add(Rescaling(1./255))
vgg_model.add(RandomFlip('horizontal_and_vertical'))
vgg_model.add(RandomRotation(0.2))
vgg_model.add(RandomZoom(0.1))
vgg_model.add(vgg_base)
vgg_model.add(Flatten())
vgg_model.add(Dense(1024, activation='relu'))
vgg_model.add(Dropout(0.5))
vgg_model.add(Dense(num_classes, activation='softmax'))

vgg_model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=metrics,)

vgg_model.fit(
    train_ds, epochs=10, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# ...
# 80134624/80134624 [==============================] - 1s 0us/step
# Epoch 1/10
#   3/189 [..............................] - ETA: 37:12 - loss: 29.7000 - categorical_accuracy: 0.8499 - auc: 0.9130 - prc: 0.8948
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 19
#      12 vgg_model.add(Dense(num_classes, activation='softmax'))
#      14 vgg_model.compile(
#      15     optimizer=keras.optimizers.Adam(1e-3),
#      16     loss="categorical_crossentropy",
#      17     metrics=metrics,)
# ---> 19 vgg_model.fit(
#      20     train_ds, epochs=10, callbacks=callbacks, validation_data=val_ds,
#      21 )
#
# File c:\Users\hhben\Desktop\cs437\Final Project\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
# ...

# %%
last_model = tf.keras.Sequential([
  tf.keras.layers.InputLayer(input_shape=(image_size + (3,))),
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.RandomFlip('horizontal_and_vertical'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.1),
  tf.keras.layers.Conv2D(128, 5, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 4, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(16, 2, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(1024, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])


last_model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=metrics,)

last_model_hist = last_model.fit(
    train_ds, epochs=10, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/10
# ...
# 189/189 [==============================] - 396s 2s/step - loss: 0.5330 - categorical_accuracy: 0.7762 - auc: 0.8508 - prc: 0.8322 - val_loss: 0.3745 - val_categorical_accuracy: 0.8517 - val_auc: 0.9198 - val_prc: 0.9137 - lr: 0.0010
# Epoch 2/10
# 175/189 [==========================>...] - ETA: 45s - loss: 0.3763 - categorical_accuracy: 0.8448 - auc: 0.9137 - prc: 0.9070
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 28
#       1 last_model = tf.keras.Sequential([
#       2   tf.keras.layers.InputLayer(input_shape=(image_size + (3,))),
#       3   tf.keras.layers.Rescaling(1./255),
#    (...)
#      19   tf.keras.layers.Dense(num_classes, activation='softmax')
#      20 ])
#      23 last_model.compile(
#      24     optimizer=keras.optimizers.Adam(1e-3),
#      25     loss="categorical_crossentropy",
#      26     metrics=metrics,)
# ...

# %%
#save the model
model2.save("mask_compliance.h5")
